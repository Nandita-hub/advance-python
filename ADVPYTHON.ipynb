# %%
import keyword

print (keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name = "swadhin"
Name = "somya"

print(Name)
# Out:
# somya

# %%
x = 10
y = x + 12
print (y)
# Out:
# 22

# %%
x = 5
y = 3
print(x +y)
print(x / y)
print(x//y)
print(x*y)
print(x**y)
# Out:
# 8
# 1.6666666666666667
# 1
# 15
# 125

# %%
a = 7
print(a > 5 and a < 10)
print(a < 5 and a < 10)
# Out:
# True
# False

# %%
bal=0
transaction= []
while True:
    print("1. Deposit")
    print("2. Withdraw")
    print("3. Check Balance")
    print("4. Transaction History")
    print("5. Exit")
    choice=int(input("Enter your choice: "))
    if choice==1:
        amt=float(input("Enter amount to deposit: "))
        bal+=amt
        transaction.append(f"Deposited: {amt}")
        print(f"Deposited {amt} successfully.")
    elif choice==2:
        amt=float(input("Enter amount to withdraw: "))
        if amt>bal:
            print("Insufficient balance.")
        else:
            bal-=amt
            transaction.append(f"Withdrew: {amt}")
            print(f"Withdrew {amt} successfully.")
    elif choice==3:
        print(f"Current Balance: {bal}")
    elif choice==4:
        print("Transaction History:")
        for t in transaction:
            print(t)
    elif choice==5:
        print("Exiting...")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 4
# Transaction History:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 3
# Current Balance: 0
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 5
# Exiting...

# %%
a=("mango","ram",True,1)
print(a)
# Out:
# ('mango', 'ram', True, 1)

# %%
s = input("Enter a string: ")
print("Reversed string:", s[::-1])
# Out:
# Enter a string: 3
# Reversed string: 3

# %%
s = input("Enter a string: ")

upper = 0
lower = 0

for ch in s:
    if ch.isupper():
        upper += 1
    elif ch.islower():
        lower += 1

print("Uppercase letters:", upper)
print("Lowercase letters:", lower)
# Out:
# Enter a string: mousmi is great
# Uppercase letters: 0
# Lowercase letters: 13

# %%
s = input("Enter a string: ")

if s.isdigit():
    print("The string contains only digits")
else:
    print("The string does not contain only digits")
# Out:
# Enter a string: nandita18
# The string does not contain only digits

# %%
s = input("Enter a string: ")

result = s.replace(" ", "_")
print("Updated string:", result)
# Out:
# Enter a string: nandita
# Updated string: nandita

# %%
s = input("Enter a string: ")

for ch in s:
    print(ch, "=", s.count(ch))
# Out:
# Enter a string: nandita
# n = 2
# a = 2
# n = 2
# d = 1
# i = 1
# t = 1
# a = 2

# %%
s = input("Enter a string: ")
ch = input("Enter a character: ")

print("First occurrence:", s.find(ch))
print("Last occurrence:", s.rfind(ch))
# Out:
# Enter a string: mimmmmyyy
# Enter a character: dost
# First occurrence: -1
# Last occurrence: -1

# %%
s = input("Enter a string: ")
result = ""

for ch in s:
    if ch not in "aeiouAEIOU":
        result += ch

print("String without vowels:", result)
# Out:
# Enter a string: the motorbiker is running
# String without vowels: th mtrbkr s rnnng

# %%
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

if sorted(s1) == sorted(s2):
    print("The strings are anagrams")
else:
    print("The strings are not anagrams")
# Out:
# Enter first string: listen
# Enter second string: silent
# The strings are anagrams

# %%
# Out:
# <class 'generator'>

# %%
s = input("Enter a string: ")

print("Updated string:", s.title())
# Out:
# Enter a string: nandita
# Updated string: Nandita

# %%
s = input("Enter a string: ")
flag = True

for i in range(len(s)//2):
    if s[i] != s[len(s)-i-1]:
        flag = False
        break

if flag:
    print("The string is a palindrome")
else:
    print("The string is not a palindrome")
# Out:
# Enter a string: madam
# The string is a palindrome

# %%
a= [1,2,3,4]
b=[2,4,6,8]
print(a+b)
# Out:
# [1, 2, 3, 4, 2, 4, 6, 8]

# %%
a = set()
b = set()
n = int(input("Enter the number of students: "))
for i in range(n):
    name = input("Enter the name of the student: ")
    if name in a:
        b.add(name)
        print(name, "is FAKE (already exists)")
    else:
        a.add(name)
        print(name, "is REAL (added successfully)")

print("\nReal students:", a)
print("Fake students:", b)
# Out:
# Enter the number of students: 4
# Enter the name of the student: nandita
# nandita is REAL (added successfully)
# Enter the name of the student: mousmi
# mousmi is REAL (added successfully)
# Enter the name of the student: bhumika
# bhumika is REAL (added successfully)
# Enter the name of the student: mousmi
# mousmi is FAKE (already exists)
#
# Real students: {'nandita', 'mousmi', 'bhumika'}
# Fake students: {'mousmi'}

# %%
numbers = list(map(int, input().split()))


avg = sum(numbers) / len(numbers)


count = sum(1 for x in numbers if x > avg)



print(count)
# Out:
# 23
# 0

# %%
temps = list(map(int, input().split()))


unsafe = [t for t in temps if t > 50]


if unsafe:
    print(*unsafe)
else:
    print(0)
# Out:
# 34
# 0

# %%
arr = list(map(int, input().split()))


is_increasing = True
for i in range(1, len(arr)):
    if arr[i] <= arr[i - 1]:
        is_increasing = False
        break



print(is_increasing)
# Out:
# 45
# True

# %%
words = input().split(',')


min_len = min(len(word) for word in words)


for word in reversed(words):
    if len(word) == min_len:
        print(word)
        break
# Out:
# nandita
# nandita

# %%
import math


nums = list(map(float, input().split()))

floored = [str(math.floor(n)) for n in nums]


print(",".join(floored))
# Out:
# 12
# 12

# %%
import math


words = input().split(',')


lengths = [len(word) for word in words]


avg_ceiling = math.ceil(sum(lengths) / len(lengths))


count = sum(1 for l in lengths if l > avg_ceiling)


print(count)

# %%
# transaction System:
balance = 0
transactions = []

PASSWORD = "231807"
attempts = 3

# Password check:
while attempts > 0:
    user_pass = input("Enter your password: ")

    if user_pass == PASSWORD:
        print("Login successful!")
        break
    else:
        attempts -= 1
        print("Wrong password attempts left:", attempts)

if attempts == 0:
    print("Too many wrong attempts")
else:

  while True:
    print("\n1.Deposit")
    print("2.Withdraw")
    print("3.CheckBalance")
    print("4.Transaction History")
    print("5.Exit")

    choice= int(input("Enter your choice:"))
    if choice == 1:
        amt = int(input("Enter Deposit Amount"))
        balance +=amt
        transactions.append("Deposited" + str(amt))
        print("Amount Deposited")

    elif choice == 2:
        amt = int(input("Enter Withdrawal Amount"))
        if amt <= balance:
            balance -=amt
            transactions.append("Withdrawl: " +str(amt))
            print("Amount Withdrawn")

        else:
            print("Insufficient Balance")

    elif choice == 3:
        print("Current Balance: ",balance)

    elif choice == 4:
        print("\nTransaction History")
        if len(transactions) == 0:
            print("No Transaction Yet")
        else:
            for t in transactions:
                print(t)

    elif choice == 5:
        print("Thank You")
        break
    else:
        print("Invalid Choice")
# Out:
# Enter your password: 231807
# Login successful!
#
# 1.Deposit
# 2.Withdraw
# 3.CheckBalance
# 4.Transaction History
# 5.Exit
# Enter your choice:1
# Enter Deposit Amount2000
# Amount Deposited
#
# 1.Deposit
# 2.Withdraw
# 3.CheckBalance
# 4.Transaction History
# 5.Exit
# Enter your choice:2
# Enter Withdrawal Amount500
# Amount Withdrawn
#
# 1.Deposit
# 2.Withdraw
# 3.CheckBalance
# 4.Transaction History
# 5.Exit
# Enter your choice:3
# Current Balance:  1500
#
# 1.Deposit
# 2.Withdraw
# 3.CheckBalance
# 4.Transaction History
# 5.Exit
# Enter your choice:4
#
# Transaction History
# Deposited2000
# Withdrawl: 500
#
# 1.Deposit
# 2.Withdraw
# 3.CheckBalance
# 4.Transaction History
# 5.Exit
# Enter your choice:1
# Enter Deposit Amount500
# Amount Deposited
#
# 1.Deposit
# 2.Withdraw
# 3.CheckBalance
# 4.Transaction History
# 5.Exit
# Enter your choice:3
# Current Balance:  2000
#
# 1.Deposit
# 2.Withdraw
# 3.CheckBalance
# 4.Transaction History
# 5.Exit
# Enter your choice:5
# ...

# %%
hostel = {}

n = int(input("Enter number of rooms: "))
for i in range(n):
    room = int(input("Enter room number: "))
    hostel[room] = None   # None means empty room

while True:
    print("\n1. Check room availability")
    print("2. Allot a room")
    print("3. Show occupied and empty rooms")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        for room in hostel:
            if hostel[room] is None:
                print("Room", room, "is available")
            else:
                print("Room", room, "is occupied")

    elif choice == 2:
        room = int(input("Enter room number: "))
        if room in hostel:
            if hostel[room] is None:
                name = input("Enter student name: ")
                sid = input("Enter student ID: ")
                hostel[room] = {"Name": name, "ID": sid}
                print("Room booked")
            else:
                print("Room already occupied")
        else:
            print("Invalid room number")

    elif choice == 3:
        empty = 0
        occupied = 0

        for room in hostel:
            if hostel[room] is None:
                empty += 1
            else:
                occupied += 1

        print("Empty rooms:", empty)
        print("Occupied rooms:", occupied)

    elif choice == 4:
        print("Exit")
        break

    else:
        print("Wrong choice")
# Out:
# Enter number of rooms: 5
# Enter room number: 201
# Enter room number: 202
# Enter room number: 203
# Enter room number: 204
# Enter room number: 205
#
# 1. Check room availability
# 2. Allot a room
# 3. Show occupied and empty rooms
# 4. Exit
# Enter your choice: 1
# Room 201 is available
# Room 202 is available
# Room 203 is available
# Room 204 is available
# Room 205 is available
#
# 1. Check room availability
# 2. Allot a room
# 3. Show occupied and empty rooms
# 4. Exit
# Enter your choice: 2
# Enter room number: 201
# Enter student name: nandita
# Enter student ID: 24cseaiml324
# Room booked
#
# 1. Check room availability
# 2. Allot a room
# 3. Show occupied and empty rooms
# 4. Exit
# Enter your choice: 2
# Enter room number: 202
# Enter student name: mousmi
# Enter student ID: 24cseaiml319
# Room booked
#
# 1. Check room availability
# 2. Allot a room
# 3. Show occupied and empty rooms
# 4. Exit
# Enter your choice: 2
# Enter room number: 203
# Enter student name: bhumika
# ...

# %%
# set questions
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5, 6]

common = set(list1) & set(list2)
print(common)
# Out:
# {3, 4}

# %%
sentence = "python is easy and python is powerful"

result = " ".join(set(sentence.split()))
print(result)
# Out:
# and easy is python powerful

# %%
str1 = "listen"
str2 = "silent"

if set(str1) == set(str2) and len(str1) == len(str2):
    print("Anagrams")
else:
    print("Not Anagrams")
# Out:
# Anagrams

# %%
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5]

result = set(list1) - set(list2)
print(result)
# Out:
# {1, 2}

# %%
string = "python"

if len(string) == len(set(string)):
    print("All characters are unique")
else:
    print("Duplicate characters found")
# Out:
# All characters are unique

# %%
numbers = [1, 2, 2, 3, 4, 4, 5]

count = len(set(numbers))
print(count)
# Out:
# 5

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}

result = set1 ^ set2
print(result)
# Out:
# {1, 2, 4, 5}

# %%
str1 = "hello"
str2 = "world"

common = set(str1) & set(str2)

print("String1:", "".join(set(str1) - common))
print("String2:", "".join(set(str2) - common))
# Out:
# String1: eh
# String2: dwr

# %%
set1 = {1, 2}
set2 = {1, 2, 3, 4}

print(set1.issubset(set2))
# Out:
# True

# %%
#Set-Based Event Tracker System

events = set()

while True:
    print("\n1. Add Event")
    print("2. Remove Event")
    print("3. View Events")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        event = input("Enter event name: ")
        events.add(event)
        print("Event added successfully")

    elif choice == 2:
        event = input("Enter event name to remove: ")
        events.discard(event)
        print("Event removed (if it existed)")

    elif choice == 3:
        print("Current Events:", events)

    elif choice == 4:
        print("Thank you! Exiting program.")
        break

    else:
        print("Invalid choice, try again")
# Out:
# 1. Add Event
# 2. Remove Event
# 3. View Events
# 4. Exit
# Enter your choice: 1
# Enter event name: shrujan
# Event added successfully
#
# 1. Add Event
# 2. Remove Event
# 3. View Events
# 4. Exit
# Enter your choice: 1
# Enter event name: tech-fest
# Event added successfully
#
# 1. Add Event
# 2. Remove Event
# 3. View Events
# 4. Exit
# Enter your choice: 1
# Enter event name: hackathon
# Event added successfully
#
# 1. Add Event
# 2. Remove Event
# 3. View Events
# 4. Exit
# Enter your choice: 3
# Current Events: {'tech-fest', 'hackathon', 'shrujan'}
#
# 1. Add Event
# 2. Remove Event
# 3. View Events
# 4. Exit
# Enter your choice: 2
# Enter event name to remove: tech-fest
# Event removed (if it existed)
#
# 1. Add Event
# 2. Remove Event
# 3. View Events
# 4. Exit
# Enter your choice: 3
# Current Events: {'hackathon', 'shrujan'}
#
# 1. Add Event
# 2. Remove Event
# 3. View Events
# 4. Exit
# Enter your choice: 4
# Thank you! Exiting program.

# %%
n = int(input("Enter number of students: "))

students = {}

for i in range(n):
    name = input("Enter student name: ")
    marks = int(input("Enter marks: "))
    students[name] = marks

highest_marks = max(students.values())


topper = max(students, key=students.get)


print("Highest Marks:", highest_marks)
print("Student with Highest Marks:", topper)
# Out:
# Enter number of students: 3
# Enter student name: nandita
# Enter marks: 90
# Enter student name: mousmi
# Enter marks: 89
# Enter student name: bhumika
# Enter marks: 88
# Highest Marks: 90
# Student with Highest Marks: nandita

# %%
#find common elements between two lists using set
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]

common = list(set(list1) & set(list2))
print(f"Common elements: {common}")
# Out:
# Common elements: [4, 5]

# %%
#remove duplicate word from a sentence using set
sentence = "python is great and python is fast"
words = sentence.split()
unique_words = " ".join(set(words))

print(f"Unique words: {unique_words}")
# Out:
# Unique words: is python and great fast

# %%
#check if two strings are anagrams using set and logic
str1 = "listen"
str2 = "silent"

is_anagram = set(str1) == set(str2) and len(str1) == len(str2)
print(f"Are they anagrams? {is_anagram}")
# Out:
# Are they anagrams? True

# %%
#find element present in first list but not in second using set
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5, 6]

difference = list(set(list1) - set(list2))
print(f"In list1 but not list2: {difference}")
# Out:
# In list1 but not list2: [1, 2]

# %%
#check if all the character in a string are unique using set
text = "python"
is_unique = len(set(text)) == len(text)

print(f"Are all characters unique? {is_unique}")
# Out:
# Are all characters unique? True

# %%
#count number of distinct elements in a list using set
my_list = [10, 20, 10, 30, 20, 40]
distinct_count = len(set(my_list))

print(f"Number of distinct elements: {distinct_count}")
# Out:
# Number of distinct elements: 4

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}


union = set1 | set2
intersection = set1 & set2
sym_diff = union - intersection

print(f"Symmetric difference: {sym_diff}")
# Out:
# Symmetric difference: {1, 2, 5, 6}

# %%
s1 = "apple"
s2 = "pear"

common = set(s1) & set(s2)


result1 = "".join([char for char in s1 if char not in common])
result2 = "".join([char for char in s2 if char not in common])

print(f"String 1 cleaned: {result1}")
print(f"String 2 cleaned: {result2}")
# Out:
# String 1 cleaned: l
# String 2 cleaned: r

# %%
small_set = {1, 2}
big_set = {1, 2, 3, 4}


is_subset = (small_set & big_set) == small_set

print(f"Is it a subset? {is_subset}")
# Out:
# Is it a subset? True

# %%
my_list = [1, 2, 3, 1, 2, 4]
seen = set()
repeats = set()

for item in my_list:
    if item in seen:
        repeats.add(item)
    else:
        seen.add(item)

print(f"Repeated elements: {repeats}")
# Out:
# Repeated elements: {1, 2}

# %%
balance = 0
transactions = []

PASSWORD = "231807"
MAX_ATTEMPTS = 3


def check_password():
    attempts = MAX_ATTEMPTS
    while attempts > 0:
        user_pass = input("Enter your password: ")
        if user_pass == PASSWORD:
            print("Login successful!")
            return True
        else:
            attempts -= 1
            print("Wrong password attempts left:", attempts)

    print("Too many wrong attempts")
    return False


def deposit():
    global balance
    amt = int(input("Enter Deposit Amount: "))
    balance += amt
    transactions.append("Deposited: " + str(amt))
    print("Amount Deposited")


def withdraw():
    global balance
    amt = int(input("Enter Withdrawal Amount: "))
    if amt <= balance:
        balance -= amt
        transactions.append("Withdrawn: " + str(amt))
        print("Amount Withdrawn")
    else:
        print("Insufficient Balance")


def check_balance():
    print("Current Balance:", balance)


def show_transactions():
    print("\nTransaction History")
    if len(transactions) == 0:
        print("No Transactions Yet")
    else:
        for t in transactions:
            print(t)


def menu():
    while True:
        print("\n1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Transaction History")
        print("5. Exit")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            deposit()
        elif choice == 2:
            withdraw()
        elif choice == 3:
            check_balance()
        elif choice == 4:
            show_transactions()
        elif choice == 5:
            print("Thank You")
            break
        else:
            print("Invalid Choice")


# Main Program
if check_password():
    menu()
# Out:
# Enter your password: 231807
# Login successful!
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 1
# Enter Deposit Amount: 5000
# Amount Deposited
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 2
# Enter Withdrawal Amount: 1000
# Amount Withdrawn
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 3
# Current Balance: 4000
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 4
#
# Transaction History
# Deposited: 5000
# Withdrawn: 1000
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 5
# Thank You

# %%
accounts = {
    101: {"password": "01", "balance": 2000, "history": []},
    102: {"password": "02", "balance": 4000, "history": []},
    103: {"password": "03", "balance": 6000, "history": []},
    104: {"password": "04", "balance": 8000, "history": []},
    105: {"password": "05", "balance": 10000, "history": []}
}

current_account = None
MAX_ATTEMPTS = 4


# --------- FUNCTIONS ---------

def login():
    global current_account
    acc = int(input("Enter Account Number: "))

    if acc in accounts:
        attempts = MAX_ATTEMPTS
        while attempts > 0:
            pwd = input("Enter Password: ")
            if pwd == accounts[acc]["password"]:
                current_account = acc
                print("Login Successful")
                return
            else:
                attempts -= 1
                print("Wrong Password, attempts left:", attempts)
        print("Too many wrong attempts")
    else:
        print("Account not found")


def deposit():
    amt = int(input("Enter Deposit Amount: "))
    accounts[current_account]["balance"] += amt
    accounts[current_account]["history"].append("Deposited " + str(amt))
    print("Amount Deposited")


def withdraw():
    amt = int(input("Enter Withdrawal Amount: "))
    if amt <= accounts[current_account]["balance"]:
        accounts[current_account]["balance"] -= amt
        accounts[current_account]["history"].append("Withdrawn " + str(amt))
        print("Amount Withdrawn")
    else:
        print("Insufficient Balance")


def check_balance():
    print("Balance:", accounts[current_account]["balance"])


def show_history():
    print("Transaction History:")
    history = accounts[current_account]["history"]
    if len(history) == 0:
        print("No Transactions Yet")
    else:
        for h in history:
            print(h)


def logout():
    global current_account
    current_account = None
    print("Account Switched")


def atm_menu():
    while True:
        print("\n1.Deposit")
        print("2.Withdraw")
        print("3.Check Balance")
        print("4.Transaction History")
        print("5.Switch Account")
        print("6.Exit")

        ch = int(input("Enter Choice: "))

        if ch == 1:
            deposit()
        elif ch == 2:
            withdraw()
        elif ch == 3:
            check_balance()
        elif ch == 4:
            show_history()
        elif ch == 5:
            logout()
            break
        elif ch == 6:
            print("Thank You")
            exit()
        else:
            print("Invalid Choice")


# --------- MAIN PROGRAM ---------

while True:
    if current_account is None:
        print("\n1.Login")
        print("2.Exit")
        choice = int(input("Enter Choice: "))

        if choice == 1:
            login()
        elif choice == 2:
            print("ATM Closed")
            break
        else:
            print("Invalid Choice")
    else:
        atm_menu()
# Out:
# 1.Login
# 2.Exit
# Enter Choice: 1
# Enter Account Number: 101
# Enter Password: 01
# Login Successful
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction History
# 5.Switch Account
# 6.Exit
# Enter Choice: 1
# Enter Deposit Amount: 1000
# Amount Deposited
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction History
# 5.Switch Account
# 6.Exit
# Enter Choice: 3
# Balance: 3000
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction History
# 5.Switch Account
# 6.Exit
# Enter Choice: 4
# Transaction History:
# Deposited 1000
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction History
# 5.Switch Account
# 6.Exit
# Enter Choice: 5
# Account Switched
#
# 1.Login
# 2.Exit
# Enter Choice: 1
# Enter Account Number: 102
# Enter Password: 02
# Login Successful
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction History
# 5.Switch Account
# 6.Exit
# Enter Choice: 1
# Enter Deposit Amount: 500
# Amount Deposited
#
# 1.Deposit
# 2.Withdraw
# ...

# %%
# --------- CREATE ACCOUNTS USING USER INPUT ---------

accounts = {}
current_account = None
MAX_ATTEMPTS = 4

n = int(input("Enter number of accounts to create: "))

for i in range(n):
    acc_no = int(input("Enter Account Number: "))
    pwd = input("Set Password: ")
    bal = int(input("Enter Initial Balance: "))

    accounts[acc_no] = {
        "password": pwd,
        "balance": bal,
        "history": []
    }

print("Accounts Created Successfully")


# --------- FUNCTIONS ---------

def login():
    global current_account
    acc = int(input("Enter Account Number: "))

    if acc in accounts:
        attempts = MAX_ATTEMPTS
        while attempts > 0:
            pwd = input("Enter Password: ")
            if pwd == accounts[acc]["password"]:
                current_account = acc
                print("Login Successful")
                return
            else:
                attempts -= 1
                print("Wrong Password, attempts left:", attempts)
        print("Too many wrong attempts")
    else:
        print("Account not found")


def deposit():
    amt = int(input("Enter Deposit Amount: "))
    accounts[current_account]["balance"] += amt
    accounts[current_account]["history"].append("Deposited " + str(amt))
    print("Amount Deposited")


def withdraw():
    amt = int(input("Enter Withdrawal Amount: "))
    if amt <= accounts[current_account]["balance"]:
        accounts[current_account]["balance"] -= amt
        accounts[current_account]["history"].append("Withdrawn " + str(amt))
        print("Amount Withdrawn")
    else:
        print("Insufficient Balance")


def check_balance():
    print("Balance:", accounts[current_account]["balance"])


def show_history():
    print("Transaction History:")
    history = accounts[current_account]["history"]
    if len(history) == 0:
        print("No Transactions Yet")
    else:
        for h in history:
            print(h)


def logout():
    global current_account
    current_account = None
    print("Account Switched")


def atm_menu():
    while True:
        print("\n1.Deposit")
        print("2.Withdraw")
        print("3.Check Balance")
        print("4.Transaction History")
        print("5.Switch Account")
        print("6.Exit")

        ch = int(input("Enter Choice: "))

        if ch == 1:
            deposit()
        elif ch == 2:
            withdraw()
        elif ch == 3:
            check_balance()
        elif ch == 4:
            show_history()
        elif ch == 5:
            logout()
            break
        elif ch == 6:
            print("Thank You")
            exit()
        else:
            print("Invalid Choice")


# --------- MAIN PROGRAM ---------

while True:
    if current_account is None:
        print("\n1.Login")
        print("2.Exit")
        choice = int(input("Enter Choice: "))

        if choice == 1:
            login()
        elif choice == 2:
            print("ATM Closed")
            break
        else:
            print("Invalid Choice")
    else:
        atm_menu()
# Out:
# Enter number of accounts to create: 4
# Enter Account Number: 201
# Set Password: n
# Enter Initial Balance: 5000
# Enter Account Number: 202
# Set Password: b
# Enter Initial Balance: 5000
# Enter Account Number: 203
# Set Password: c
# Enter Initial Balance: 4000
# Enter Account Number: 204
# Set Password: m
# Enter Initial Balance: 6000
# Accounts Created Successfully
#
# 1.Login
# 2.Exit
# Enter Choice: 1
# Enter Account Number: 203
# Enter Password: c
# Login Successful
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction History
# 5.Switch Account
# 6.Exit
# Enter Choice: 6
# Thank You
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction History
# 5.Switch Account
# 6.Exit
# Enter Choice: 5
# Account Switched
#
# 1.Login
# 2.Exit
# Enter Choice: 2
# ATM Closed

# %%
def divisors(n):
    result = []
    for i in range(1, n + 1):
        if n % i == 0:
            result.append(i)
    return result


def common_divisors(a, b):
    result = []
    limit = min(a, b)
    for i in range(1, limit + 1):
        if a % i == 0 and b % i == 0:
            result.append(i)
    return result


def divisors_upto(n):
    div_dict = {}
    for num in range(1, n + 1):
        div_list = []
        for i in range(1, num + 1):
            if num % i == 0:
                div_list.append(i)
        div_dict[num] = div_list
    return div_dict

# %%
def top_student(records):
    top_name = None
    top_total = -1

    for name in records:
        total = sum(records[name])
        if total > top_total:
            top_total = total
            top_name = name

    return top_name

# %%
def char_frequency(s):
    freq = {}
    for ch in s:
        if ch in freq:
            freq[ch] += 1
        else:
            freq[ch] = 1
    return freq
